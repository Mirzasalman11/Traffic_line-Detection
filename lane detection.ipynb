# %% [markdown]
# finally

# %%
import numpy as np
import pandas as pd
import cv2
from ultralytics import YOLO
model = YOLO('C:/salman/sir_pro/runs/detect/train/weights/best.pt')


class LaneDetectionAPI:



    def __init__(self, video_path=0):
        self.video_path = video_path
        self.cap = None




    def canny_detector(self,image):

        
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        
        # Create masks for white and yellow color    
        lower_white = np.array([0, 0, 200], dtype=np.uint8)
        upper_white = np.array([180, 30, 255], dtype=np.uint8)
        lower_yellow = np.array([20, 100, 100], dtype=np.uint8)
        upper_yellow = np.array([40, 255, 255], dtype=np.uint8)
        
        white_mask = cv2.inRange(hsv, lower_white, upper_white)
        yellow_mask = cv2.inRange(hsv, lower_yellow, upper_yellow)
        
        # Combine the masks to get the final mask
        combined_mask = cv2.bitwise_or(white_mask, yellow_mask)
        
        # Apply the mask to the original image
        masked_image = cv2.bitwise_and(image, image, mask=combined_mask)
        
        # Convert the masked image to grayscale
        grayscale = cv2.cvtColor(masked_image, cv2.COLOR_BGR2GRAY)


        # Apply Gaussian blur to reduce noise
        blurred = cv2.GaussianBlur(grayscale, (9,9), 0)

        # Apply Canny edge detection
        edges = cv2.Canny(blurred, 100, 200)

        return edges


    def region_selection(self,image):
        """
        Determine and cut the region of interest in the input image.
            Parameters:
                image: An np.array compatible with plt.imshow.
        """
        mask = np.zeros_like(image)   
        #Defining a 3 channel or 1 channel color to fill the mask with depending on the input image
        if len(image.shape) > 2:
            channel_count = image.shape[2]
            ignore_mask_color = (255,) * channel_count
        else:
            ignore_mask_color = 255
        #We could have used fixed numbers as the vertices of the polygon,
        #but they will not be applicable to images with different dimesnions.
        rows, cols = image.shape[:2]
        bottom_left  = [cols * 0.1, rows * 0.95]
        top_left     = [cols * 0.4, rows * 0.62]
        bottom_right = [cols * 0.9, rows * 0.95]
        top_right    = [cols * 0.6, rows * 0.62]
        vertices = np.array([[bottom_left, top_left, top_right, bottom_right]], dtype=np.int32)
        cv2.fillPoly(mask, vertices, ignore_mask_color)
        masked_image = cv2.bitwise_and(image, mask)
        return masked_image


    def hough_transform(self,image):
        """
        Determine and cut the region of interest in the input image.
            Parameters:
                image: The output of a Canny transform.
        """
        rho = 1              #Distance resolution of the accumulator in pixels.
        theta = np.pi/180    #Angle resolution of the accumulator in radians.
        threshold = 20       #Only lines that are greater than threshold will be returned.
        minLineLength = 20   #Line segments shorter than that are rejected.
        maxLineGap = 300     #Maximum allowed gap between points on the same line to link them
        return cv2.HoughLinesP(image, rho = rho, theta = theta, threshold = threshold,
                            minLineLength = minLineLength, maxLineGap = maxLineGap)



    def draw_lines(self,image, lines, color = [255, 0, 0], thickness = 3):
        """
        Draw lines onto the input image.
            Parameters:
                image: An np.array compatible with plt.imshow.
                lines: The lines we want to draw.
                color (Default = red): Line color.
                thickness (Default = 2): Line thickness.
        """
        image = np.copy(image)
        for line in lines:
            for x1,y1,x2,y2 in line:
                cv2.line(image, (x1, y1), (x2, y2), color, thickness)
        return image



    def average_slope_intercept(self,lines):
        """
        Find the slope and intercept of the left and right lanes of each image.
            Parameters:
                lines: The output lines from Hough Transform.
        """
        if lines is None:
            return None, None

        left_lines    = [] #(slope, intercept)
        left_weights  = [] #(length,)
        right_lines   = [] #(slope, intercept)
        right_weights = [] #(length,)
        
        for line in lines:
            for x1, y1, x2, y2 in line:
                if x1 == x2:
                    continue
                slope = (y2 - y1) / (x2 - x1)
                intercept = y1 - (slope * x1)
                length = np.sqrt(((y2 - y1) ** 2) + ((x2 - x1) ** 2))
                if slope < 0:
                    left_lines.append((slope, intercept))
                    left_weights.append((length))
                else:
                    right_lines.append((slope, intercept))
                    right_weights.append((length))
        left_lane  = np.dot(left_weights,  left_lines) / np.sum(left_weights)  if len(left_weights) > 0 else None
        right_lane = np.dot(right_weights, right_lines) / np.sum(right_weights) if len(right_weights) > 0 else None
        return left_lane, right_lane


    def pixel_points(self,y1, y2, line):
        """
        Converts the slope and intercept of each line into pixel points.
            Parameters:
                y1: y-value of the line's starting point.
                y2: y-value of the line's end point.
                line: The slope and intercept of the line.
        """
        if line is None:
            return None

        slope, intercept = line
        
        # Check if the slope is not equal to zero (not vertical)
        if slope != 0:
            x1 = int((y1 - intercept) / slope)
            x2 = int((y2 - intercept) / slope)
            y1 = int(y1)
            y2 = int(y2)
            return ((x1, y1), (x2, y2))
        else:
            return None


    def lane_lines(self,image, lines):
        """
        Create full lenght lines from pixel points.
            Parameters:
                image: The input test image.
                lines: The output lines from Hough Transform.
        """
        left_lane, right_lane = self.average_slope_intercept(lines)
        y1 = image.shape[0]
        y2 = y1 * 0.6
        left_line  = self.pixel_points(y1, y2, left_lane)
        right_line = self.pixel_points(y1, y2, right_lane)
        return left_line, right_line

        
    def draw_lane_lines(self,image, lines, color=[0, 255, 0], thickness=3):
        """
        Draw lines onto the input image.
            Parameters:
                image: The input test image.
                lines: The output lines from Hough Transform.
                color (Default = red): Line color.
                thickness (Default = 12): Line thickness. 
        """
        line_image = np.zeros_like(image)
        for line in lines:
            if line is not None:
                cv2.line(line_image, *line,  color, thickness)
        return cv2.addWeighted(image, 1.0, line_image, 1.0, 0.0)



    def frame_processor(self,image):
        """
        Process the input frame to detect lane lines.
            Parameters:
                image: Single video frame.
        """
        
        edges        = self.canny_detector(image)
        region       = self.region_selection(edges)
        hough        = self.hough_transform(region)
        result       = self.draw_lane_lines(image, self.lane_lines(image, hough))
        return result 



    def process_video(self):

        cap = cv2.VideoCapture(self.video_path)



        while (cap.isOpened()): 
            ret,frame=cap.read()
            if ret==True:
                combo_frame = self.frame_processor(frame)
                results =model.predict(source=combo_frame,show=True)
            
                if cv2.waitKey(1) & 0xFF == ord('q'):   #press to exit
                    break
            else:
                break

        cap.release()
        cv2.destroyAllWindows()

# %%
api = LaneDetectionAPI("ved.mp4")
api.process_video()
# Out:
# 0: 384x640 (no detections), 238.4ms
# Speed: 3.0ms preprocess, 238.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 416.8ms
# Speed: 23.0ms preprocess, 416.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 189.5ms
# Speed: 4.8ms preprocess, 189.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.4ms
# Speed: 4.0ms preprocess, 214.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.5ms
# Speed: 3.0ms preprocess, 177.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 190.5ms
# Speed: 1.9ms preprocess, 190.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.5ms
# Speed: 4.9ms preprocess, 178.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 203.5ms
# Speed: 2.9ms preprocess, 203.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.5ms
# Speed: 3.0ms preprocess, 167.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.5ms
# Speed: 2.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 177.5ms
# Speed: 5.0ms preprocess, 177.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.5ms
# Speed: 2.9ms preprocess, 166.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 209.4ms
# Speed: 3.4ms preprocess, 209.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.6ms
# Speed: 3.0ms preprocess, 167.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.5ms
# Speed: 3.0ms preprocess, 169.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.5ms
# Speed: 2.9ms preprocess, 179.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 176.5ms
# Speed: 4.0ms preprocess, 176.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 192.5ms
# Speed: 5.0ms preprocess, 192.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.6ms
# Speed: 4.0ms preprocess, 164.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 185.5ms
# Speed: 2.0ms preprocess, 185.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 172.5ms
# Speed: 2.0ms preprocess, 172.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 199.5ms
# Speed: 3.9ms preprocess, 199.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 188.5ms
# Speed: 3.8ms preprocess, 188.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 166.6ms
# Speed: 2.9ms preprocess, 166.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 191.5ms
# Speed: 3.0ms preprocess, 191.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 167.5ms
# Speed: 5.0ms preprocess, 167.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.5ms
# Speed: 4.0ms preprocess, 179.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 168.5ms
# Speed: 4.0ms preprocess, 168.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 185.5ms
# Speed: 2.8ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 170.5ms
# Speed: 5.0ms preprocess, 170.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 188.5ms
# Speed: 3.0ms preprocess, 188.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 173.9ms
# Speed: 4.0ms preprocess, 173.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 171.5ms
# Speed: 5.0ms preprocess, 171.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 195.8ms
# Speed: 5.0ms preprocess, 195.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 182.5ms
# Speed: 5.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 267.3ms
# Speed: 2.6ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 326.7ms
# Speed: 3.0ms preprocess, 326.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 262.3ms
# Speed: 8.0ms preprocess, 262.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 304.2ms
# Speed: 4.0ms preprocess, 304.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 194.5ms
# Speed: 3.0ms preprocess, 194.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 281.0ms
# Speed: 11.5ms preprocess, 281.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 233.3ms
# Speed: 4.0ms preprocess, 233.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 199.7ms
# Speed: 7.0ms preprocess, 199.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 277.9ms
# Speed: 10.0ms preprocess, 277.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 224.5ms
# Speed: 9.0ms preprocess, 224.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 240.7ms
# Speed: 3.0ms preprocess, 240.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 266.3ms
# Speed: 3.0ms preprocess, 266.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 332.9ms
# Speed: 22.6ms preprocess, 332.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 314.6ms
# Speed: 5.8ms preprocess, 314.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 200.6ms
# Speed: 9.0ms preprocess, 200.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 206.0ms
# Speed: 3.5ms preprocess, 206.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 184.7ms
# Speed: 3.4ms preprocess, 184.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 200.0ms
# Speed: 4.0ms preprocess, 200.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 204.8ms
# Speed: 3.0ms preprocess, 204.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 203.5ms
# Speed: 4.0ms preprocess, 203.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 182.0ms
# Speed: 2.6ms preprocess, 182.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 223.6ms
# Speed: 5.7ms preprocess, 223.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 202.5ms
# Speed: 5.0ms preprocess, 202.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 203.0ms
# Speed: 2.0ms preprocess, 203.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 205.6ms
# Speed: 10.5ms preprocess, 205.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 229.1ms
# Speed: 3.1ms preprocess, 229.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 232.1ms
# Speed: 7.0ms preprocess, 232.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 297.5ms
# Speed: 4.0ms preprocess, 297.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 277.5ms
# Speed: 8.1ms preprocess, 277.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 266.5ms
# Speed: 7.9ms preprocess, 266.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 411.8ms
# Speed: 5.0ms preprocess, 411.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 243.4ms
# Speed: 3.7ms preprocess, 243.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 188.0ms
# Speed: 5.0ms preprocess, 188.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 191.0ms
# Speed: 6.0ms preprocess, 191.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 186.6ms
# Speed: 3.0ms preprocess, 186.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 220.5ms
# Speed: 3.0ms preprocess, 220.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 196.7ms
# Speed: 3.0ms preprocess, 196.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 190.4ms
# Speed: 4.0ms preprocess, 190.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 195.6ms
# Speed: 4.0ms preprocess, 195.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 208.8ms
# Speed: 3.0ms preprocess, 208.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 200.8ms
# Speed: 4.2ms preprocess, 200.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 201.5ms
# Speed: 4.0ms preprocess, 201.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 203.0ms
# Speed: 4.0ms preprocess, 203.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.4ms
# Speed: 4.0ms preprocess, 214.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 201.5ms
# Speed: 4.0ms preprocess, 201.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 208.6ms
# Speed: 4.0ms preprocess, 208.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 197.8ms
# Speed: 3.0ms preprocess, 197.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 221.3ms
# Speed: 2.9ms preprocess, 221.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 196.9ms
# Speed: 3.5ms preprocess, 196.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 207.5ms
# Speed: 3.0ms preprocess, 207.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 178.2ms
# Speed: 3.0ms preprocess, 178.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 223.9ms
# Speed: 6.6ms preprocess, 223.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 189.1ms
# Speed: 3.0ms preprocess, 189.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 191.8ms
# Speed: 5.0ms preprocess, 191.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 204.9ms
# Speed: 3.9ms preprocess, 204.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 239.4ms
# Speed: 8.3ms preprocess, 239.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 255.6ms
# Speed: 4.0ms preprocess, 255.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 255.6ms
# Speed: 7.9ms preprocess, 255.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 212.0ms
# Speed: 5.0ms preprocess, 212.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 226.7ms
# Speed: 3.0ms preprocess, 226.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 215.7ms
# Speed: 3.0ms preprocess, 215.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 233.4ms
# Speed: 3.0ms preprocess, 233.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 196.5ms
# Speed: 4.0ms preprocess, 196.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 237.5ms
# Speed: 5.0ms preprocess, 237.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 228.8ms
# Speed: 6.0ms preprocess, 228.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.3ms
# Speed: 6.0ms preprocess, 244.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 179.5ms
# Speed: 3.0ms preprocess, 179.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 187.5ms
# Speed: 4.0ms preprocess, 187.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.5ms
# Speed: 4.0ms preprocess, 169.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 170.2ms
# Speed: 3.1ms preprocess, 170.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 198.5ms
# Speed: 3.0ms preprocess, 198.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 183.5ms
# Speed: 4.0ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 173.5ms
# Speed: 5.0ms preprocess, 173.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 1 stop, 157.6ms
# Speed: 2.0ms preprocess, 157.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 1 stop, 165.6ms
# Speed: 3.8ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 220.4ms
# Speed: 3.0ms preprocess, 220.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 164.6ms
# Speed: 3.0ms preprocess, 164.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 174.2ms
# Speed: 6.3ms preprocess, 174.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 171.5ms
# Speed: 4.0ms preprocess, 171.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 177.0ms
# Speed: 4.0ms preprocess, 177.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 187.1ms
# Speed: 4.4ms preprocess, 187.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 183.5ms
# Speed: 4.9ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 189.5ms
# Speed: 11.0ms preprocess, 189.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 187.4ms
# Speed: 3.2ms preprocess, 187.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 190.5ms
# Speed: 4.0ms preprocess, 190.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 180.5ms
# Speed: 2.9ms preprocess, 180.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 180.5ms
# Speed: 3.0ms preprocess, 180.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 201.4ms
# Speed: 4.0ms preprocess, 201.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 165.6ms
# Speed: 3.0ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 197.7ms
# Speed: 3.7ms preprocess, 197.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 413.0ms
# Speed: 3.8ms preprocess, 413.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 280.2ms
# Speed: 9.0ms preprocess, 280.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 222.4ms
# Speed: 4.0ms preprocess, 222.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 251.4ms
# Speed: 3.0ms preprocess, 251.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 246.5ms
# Speed: 11.8ms preprocess, 246.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 222.9ms
# Speed: 5.0ms preprocess, 222.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 207.1ms
# Speed: 6.0ms preprocess, 207.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 202.0ms
# Speed: 5.1ms preprocess, 202.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 246.5ms
# Speed: 3.8ms preprocess, 246.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 197.3ms
# Speed: 5.8ms preprocess, 197.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 193.7ms
# Speed: 3.0ms preprocess, 193.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 190.6ms
# Speed: 3.0ms preprocess, 190.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 211.2ms
# Speed: 3.6ms preprocess, 211.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 218.5ms
# Speed: 4.1ms preprocess, 218.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 196.6ms
# Speed: 2.9ms preprocess, 196.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 215.7ms
# Speed: 5.0ms preprocess, 215.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 217.9ms
# Speed: 3.9ms preprocess, 217.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 218.0ms
# Speed: 5.7ms preprocess, 218.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 185.5ms
# Speed: 9.0ms preprocess, 185.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 207.5ms
# Speed: 5.9ms preprocess, 207.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 244.8ms
# Speed: 7.0ms preprocess, 244.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 185.8ms
# Speed: 7.1ms preprocess, 185.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 186.3ms
# Speed: 7.0ms preprocess, 186.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 196.0ms
# Speed: 6.1ms preprocess, 196.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 201.4ms
# Speed: 5.8ms preprocess, 201.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 187.4ms
# Speed: 3.0ms preprocess, 187.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 188.6ms
# Speed: 5.0ms preprocess, 188.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 182.5ms
# Speed: 4.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 205.5ms
# Speed: 4.6ms preprocess, 205.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 214.2ms
# Speed: 6.2ms preprocess, 214.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 190.6ms
# Speed: 5.0ms preprocess, 190.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 176.0ms
# Speed: 5.0ms preprocess, 176.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 224.6ms
# Speed: 4.0ms preprocess, 224.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 198.1ms
# Speed: 4.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 190.4ms
# Speed: 4.1ms preprocess, 190.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 196.6ms
# Speed: 4.9ms preprocess, 196.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 281.8ms
# Speed: 4.0ms preprocess, 281.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 250.3ms
# Speed: 4.0ms preprocess, 250.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 185.9ms
# Speed: 6.0ms preprocess, 185.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 195.2ms
# Speed: 4.0ms preprocess, 195.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 201.0ms
# Speed: 3.0ms preprocess, 201.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 speedlimits, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 181.7ms
# Speed: 3.8ms preprocess, 181.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 189.4ms
# Speed: 3.1ms preprocess, 189.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 194.7ms
# Speed: 4.0ms preprocess, 194.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 197.0ms
# Speed: 3.0ms preprocess, 197.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 196.7ms
# Speed: 3.0ms preprocess, 196.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 186.7ms
# Speed: 3.0ms preprocess, 186.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 184.7ms
# Speed: 3.0ms preprocess, 184.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 205.4ms
# Speed: 3.1ms preprocess, 205.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 211.6ms
# Speed: 3.8ms preprocess, 211.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 2 trafficlights, 198.5ms
# Speed: 4.0ms preprocess, 198.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 194.5ms
# Speed: 3.0ms preprocess, 194.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 1 trafficlight, 204.5ms
# Speed: 2.9ms preprocess, 204.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 180.4ms
# Speed: 3.1ms preprocess, 180.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 217.0ms
# Speed: 3.0ms preprocess, 217.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 200.4ms
# Speed: 4.0ms preprocess, 200.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 302.0ms
# Speed: 17.0ms preprocess, 302.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 188.2ms
# Speed: 7.0ms preprocess, 188.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 190.7ms
# Speed: 8.0ms preprocess, 190.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 190.4ms
# Speed: 7.1ms preprocess, 190.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 205.5ms
# Speed: 6.1ms preprocess, 205.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 202.4ms
# Speed: 4.7ms preprocess, 202.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 194.1ms
# Speed: 6.0ms preprocess, 194.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 190.0ms
# Speed: 4.0ms preprocess, 190.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 200.5ms
# Speed: 5.0ms preprocess, 200.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 186.0ms
# Speed: 5.6ms preprocess, 186.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 194.6ms
# Speed: 4.3ms preprocess, 194.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 194.8ms
# Speed: 4.5ms preprocess, 194.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 197.8ms
# Speed: 5.0ms preprocess, 197.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 181.0ms
# Speed: 4.1ms preprocess, 181.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 189.0ms
# Speed: 3.0ms preprocess, 189.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 205.8ms
# Speed: 4.0ms preprocess, 205.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 198.0ms
# Speed: 5.0ms preprocess, 198.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 179.1ms
# Speed: 4.0ms preprocess, 179.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 214.4ms
# Speed: 5.9ms preprocess, 214.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 183.4ms
# Speed: 3.1ms preprocess, 183.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 200.6ms
# Speed: 4.0ms preprocess, 200.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 191.2ms
# Speed: 3.0ms preprocess, 191.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 210.6ms
# Speed: 2.0ms preprocess, 210.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 191.9ms
# Speed: 3.0ms preprocess, 191.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 200.5ms
# Speed: 4.9ms preprocess, 200.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 195.9ms
# Speed: 3.6ms preprocess, 195.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 201.5ms
# Speed: 3.0ms preprocess, 201.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 193.3ms
# Speed: 3.0ms preprocess, 193.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 204.9ms
# Speed: 3.8ms preprocess, 204.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 191.7ms
# Speed: 3.0ms preprocess, 191.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 214.1ms
# Speed: 3.7ms preprocess, 214.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 201.7ms
# Speed: 3.0ms preprocess, 201.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 182.5ms
# Speed: 5.0ms preprocess, 182.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 198.1ms
# Speed: 5.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 203.1ms
# Speed: 4.3ms preprocess, 203.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 196.7ms
# Speed: 15.0ms preprocess, 196.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 193.5ms
# Speed: 3.0ms preprocess, 193.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 198.6ms
# Speed: 4.0ms preprocess, 198.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 199.8ms
# Speed: 4.1ms preprocess, 199.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 196.2ms
# Speed: 4.0ms preprocess, 196.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 198.3ms
# Speed: 3.2ms preprocess, 198.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 197.9ms
# Speed: 3.0ms preprocess, 197.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 209.4ms
# Speed: 3.0ms preprocess, 209.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 196.0ms
# Speed: 4.0ms preprocess, 196.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 284.2ms
# Speed: 6.0ms preprocess, 284.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 300.4ms
# Speed: 4.0ms preprocess, 300.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 264.9ms
# Speed: 7.7ms preprocess, 264.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 220.0ms
# Speed: 4.0ms preprocess, 220.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 207.3ms
# Speed: 4.0ms preprocess, 207.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 217.3ms
# Speed: 4.0ms preprocess, 217.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 268.7ms
# Speed: 3.0ms preprocess, 268.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 263.9ms
# Speed: 4.0ms preprocess, 263.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 255.2ms
# Speed: 4.0ms preprocess, 255.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 334.8ms
# Speed: 43.2ms preprocess, 334.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 256.8ms
# Speed: 5.5ms preprocess, 256.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 239.0ms
# Speed: 4.4ms preprocess, 239.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 206.0ms
# Speed: 3.0ms preprocess, 206.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 206.9ms
# Speed: 3.0ms preprocess, 206.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 200.6ms
# Speed: 8.0ms preprocess, 200.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 209.7ms
# Speed: 5.0ms preprocess, 209.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 218.7ms
# Speed: 3.0ms preprocess, 218.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 212.3ms
# Speed: 6.0ms preprocess, 212.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 215.2ms
# Speed: 5.0ms preprocess, 215.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 229.0ms
# Speed: 5.1ms preprocess, 229.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 217.7ms
# Speed: 4.0ms preprocess, 217.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 203.0ms
# Speed: 5.0ms preprocess, 203.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 203.8ms
# Speed: 4.0ms preprocess, 203.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 196.2ms
# Speed: 3.6ms preprocess, 196.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 213.1ms
# Speed: 4.0ms preprocess, 213.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 219.0ms
# Speed: 3.0ms preprocess, 219.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 225.3ms
# Speed: 4.0ms preprocess, 225.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 208.6ms
# Speed: 8.8ms preprocess, 208.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 206.0ms
# Speed: 4.0ms preprocess, 206.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 195.0ms
# Speed: 8.0ms preprocess, 195.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 213.4ms
# Speed: 6.0ms preprocess, 213.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 213.4ms
# Speed: 4.7ms preprocess, 213.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 270.8ms
# Speed: 4.0ms preprocess, 270.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 269.8ms
# Speed: 6.0ms preprocess, 269.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 273.3ms
# Speed: 7.0ms preprocess, 273.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 294.1ms
# Speed: 7.0ms preprocess, 294.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 207.7ms
# Speed: 7.0ms preprocess, 207.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 223.3ms
# Speed: 3.0ms preprocess, 223.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 197.0ms
# Speed: 8.9ms preprocess, 197.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 359.6ms
# Speed: 5.0ms preprocess, 359.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 203.0ms
# Speed: 6.0ms preprocess, 203.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 197.6ms
# Speed: 4.0ms preprocess, 197.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 311.2ms
# Speed: 4.0ms preprocess, 311.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 187.7ms
# Speed: 6.0ms preprocess, 187.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 198.7ms
# Speed: 3.7ms preprocess, 198.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 188.2ms
# Speed: 4.0ms preprocess, 188.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 193.9ms
# Speed: 4.0ms preprocess, 193.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 197.0ms
# Speed: 3.0ms preprocess, 197.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 speedlimits, 210.4ms
# Speed: 2.5ms preprocess, 210.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 190.3ms
# Speed: 3.0ms preprocess, 190.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 speedlimit, 212.8ms
# Speed: 3.5ms preprocess, 212.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
